# %% [markdown]
# # Importing important libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing case study csv file

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 30
# No of Columns: 17
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# The column name present in our data that is not making much sense and will need to converted into understandable.

# %% [markdown]
# # Pitching Statistics

# %% [markdown]
# W= Win, number of games where pitcher was pitching their team took the lead.
#
# RA = Run avegare, number of runs allowed times nine divided by innings pitch.
#
# ER = Earned run, number of runs that didnot occurs as a result of error or passed balls.
#
# ERA = Earned run average, total number of earned runs, multiplied by nine.
#
# CG = Complete games, number of games where player was the only pitcher.
#
# SHO = Shutout, number of complete games pitched with no runs allowed.
#
# SV = Save, number of gameswhere the pitcher enter a game led by the pitcher's team.

# %% [markdown]
# # Batting Statistics

# %% [markdown]
# R =  Run scored, number of time player crosses the base plate.
#
# AB = At bat,plate appearances, not including bases on balls.
#
# H = Hit, reaching base because of batted.
#
# 2B = Double, Hits on which batter reaches second base safely.
#
# 3B = Triple, Hits on which batter reaches third base safely.
#
# HR = Home runs, Hits on which batter successfully touches all four bases.
#
# BB = Base on ball("also called a walk")
#
# K = Strike out , number of times that a third strike is taken.

# %% [markdown]
# # Base running statistics

# %% [markdown]
# SB = Stolen base, number of bases advanced by the runner while the ball is in the
#
# R = Runs scored, times reached home plate legally and safely.

# %% [markdown]
# # Fielding Statistics

# %% [markdown]
# E = Errors, number of times fielder fails to make a play he should have made with common effort

# %% [markdown]
# Now we are going to rename the columns in dataset.

# %%
df.rename(columns={'W': 'Wins','R':'Runs Scored','AB':'At Bat', 'H':'Hits', '2B':'Doubles', '3B':'Triples','HR':'Home Runs', 'BB':'Base on Ball','SO':'Strike Out','SB':'Stolen Base','RA':'Runs Average','ER':'Earned Runs', 'ERA':'Earned Runs Average','CG':'Complete Games','SHO':'Shut Out','SV':'Saves','E':'Errors'},inplace=True)
df.head()
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  Base on Ball  \
# 0    95          724    5575  1497      300       42        139           383
# 1    83          696    5467  1349      277       44        156           439
# 2    81          669    5439  1395      303       29        141           533
# 3    76          622    5533  1381      260       27        136           404
# 4    74          689    5605  1515      289       49        151           455
#
#    Strike Out  Stolen Base  Runs Average  Earned Runs  Earned Runs Average  \
# 0         973          104           641          601                 3.73
# 1        1264           70           700          653                 4.07
# 2        1157           86           640          584                 3.67
# 3        1231           68           701          643                 3.98
# 4        1259           83           803          746                 4.64
#
#    Complete Games  Shut Out  Saves  Errors
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wins                 30 non-null     int64
#  1   Runs Scored          30 non-null     int64
#  2   At Bat               30 non-null     int64
#  3   Hits                 30 non-null     int64
#  4   Doubles              30 non-null     int64
#  5   Triples              30 non-null     int64
#  6   Home Runs            30 non-null     int64
#  7   Base on Ball         30 non-null     int64
#  8   Strike Out           30 non-null     int64
#  9   Stolen Base          30 non-null     int64
#  10  Runs Average         30 non-null     int64
#  11  Earned Runs          30 non-null     int64
#  12  Earned Runs Average  30 non-null     float64
#  13  Complete Games       30 non-null     int64
#  14  Shut Out             30 non-null     int64
# ...

# %% [markdown]
# 1)The dataset hasonly numeric values and no columns has categorical data.
#
# 2)The datast fall into regression analysis

# %% [markdown]
# # Develop an ML based Algorithm that predict the number of wins for a given team based on features.Here Wins is target variable and others are input features.

# %% [markdown]
# # Statistical Analysis

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.describe(),linewidths=0.1, fmt='0.1f',annot=True)
# Out:
# <Axes: >

# %%
df.describe().T
# Out:
#                      count         mean         std      min        25%  \
# Wins                  30.0    80.966667   10.453455    63.00    74.0000
# Runs Scored           30.0   688.233333   58.761754   573.00   651.2500
# At Bat                30.0  5516.266667   70.467372  5385.00  5464.0000
# Hits                  30.0  1403.533333   57.140923  1324.00  1363.0000
# Doubles               30.0   274.733333   18.095405   236.00   262.2500
# Triples               30.0    31.300000   10.452355    13.00    23.0000
# Home Runs             30.0   163.633333   31.823309   100.00   140.2500
# Base on Ball          30.0   469.100000   57.053725   375.00   428.2500
# Strike Out            30.0  1248.200000  103.759470   973.00  1157.5000
# Stolen Base           30.0    83.500000   22.815225    44.00    69.0000
# Runs Average          30.0   688.233333   72.108005   525.00   636.2500
# Earned Runs           30.0   635.833333   70.140786   478.00   587.2500
# ...

# %% [markdown]
# # Checking for the null values

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
missing_values=df.isnull().sum().sort_values(ascending=False)
percentage_missing_values = (missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values],axis=1, keys=['Missing Values','% Missing data']))
# Out:
#                      Missing Values  % Missing data
# Wins                              0             0.0
# Stolen Base                       0             0.0
# Saves                             0             0.0
# Shut Out                          0             0.0
# Complete Games                    0             0.0
# Earned Runs Average               0             0.0
# Earned Runs                       0             0.0
# Runs Average                      0             0.0
# Strike Out                        0             0.0
# Runs Scored                       0             0.0
# Base on Ball                      0             0.0
# Home Runs                         0             0.0
# Triples                           0             0.0
# Doubles                           0             0.0
# Hits                              0             0.0
# At Bat                            0             0.0
# Errors                            0             0.0

# %% [markdown]
# There is no null present in the dataset.

# %% [markdown]
# # EDA

# %% [markdown]
# Here we can try to bring insight in what feature

# %% [markdown]
# # Distribution of Features

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column], color='r', hist=False,kde_kws={"shade":True})
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
        plt.show()

# %% [markdown]
# So some of the features are either left or right skewed.

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,30), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column, fontsize=20)
        plotnumber+=1
        plt.show()

# %% [markdown]
# # Comment

# %% [markdown]
# 1.Shut out and complete game occurs very rarely wwhinch can be seen in violin plot.
#
# 2.An error does not count as an hit or an at bat for the batter
#
# 3. Most of the saves are between 30 & 50.
#
# 4. Run average , Earned run and Earned run average are important for the pitcher statisticss.
#
# 5.Home run (125 to 175 peak) are more than tripple(20 to 40 majority). So most of good shot by batter direct convert into home run.
#
# 6.As we know pichter try to keep Earned run average low which eventually leads to win.
#
# 7. Now lets consider violin plot of doubles and base on ball.

# %% [markdown]
# # Now we will put insight on hits converted into runs and inturn leads to win through multivariate analysis

# %%
# Checking the relation between two variant

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs and Hits', fontsize=20)
sns.scatterplot(x=df['Runs Scored'],y=df['Hits'],hue=df['Wins'])
plt.xlabel('Runs', fontsize =16)
plt.ylabel('Hits',fontsize =16)
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# # Comment

# %% [markdown]
# 1.Number of times ball hit bat is less than 1375 still runs in range of the 650 to 750 contribute to win.
#
# 2.Very less winnig chances for runs less than 650 and no on Hits less than1325.
#
# 3.there is one outlier in runs, after checking the skewnesswe can decide whether to keep While building ML model or remove it.

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs Scores and Home Runs', fontsize=20)
sns.scatterplot(x=df['Runs Scored'],y=df['Home Runs'],hue=df['Wins'])
plt.xlabel('Runs Scored', fontsize =16)
plt.ylabel('Home Runs',fontsize =16)
# Out:
# Text(0, 0.5, 'Home Runs')

# %% [markdown]
# # Comments

# %% [markdown]
# 1.Home runs in range of 140 & 180 with combination of Runs Scored in between 650-750 leads to more than 90 wins for team.
#
# 2.Anything is possible with good performance of single winning player.

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs Scored and At Bat', fontsize=20)
sns.scatterplot(x=df['Runs Scored'],y=df['At Bat'],hue=df['Wins'])
plt.xlabel('Runs Scored', fontsize =16)
plt.ylabel('At Bat',fontsize =16)
# Out:
# Text(0, 0.5, 'At Bat')

# %% [markdown]
# # Comments

# %% [markdown]
# 1.We doesn't get benchmark range for At Bat from here so it is matter that how much At Bats matter to winning statistics.
#  We get here that At Bats and Runs Scored has positive linear relationship.

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between Runs Scored and Strike Out', fontsize=20)
sns.scatterplot(x=df['Runs Scored'],y=df['Strike Out'],hue=df['Wins'])
plt.xlabel('Runs Scored', fontsize =16)
plt.ylabel('Strike Out',fontsize =16)
# Out:
# Text(0, 0.5, 'Strike Out')

# %% [markdown]
# # Comments

# %% [markdown]
# We can see Strike Out opponent team below 700 Runs essential for more win.
# Clearly Strike out below 1200 is like losing game.

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between Errors and Earned Run Average', fontsize=20)
sns.scatterplot(x=df['Errors'],y=df['Earned Runs Average'],hue=df['Wins'], cmap=('Spectral'))
plt.xlabel('Errors', fontsize =16)
plt.ylabel('Earned Runs Average',fontsize =16)
# Out:
# Text(0, 0.5, 'Earned Runs Average')

# %% [markdown]
# # Comments

# %% [markdown]
# 1. Same result about ERA as we got in violin plot.
# 2.Keeping ERA below 3.5 or as much as low by pitchermeans sure wins.

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[10,6])
plt.title('Comparison between At Bat and Base on Balls', fontsize=20)
sns.scatterplot(x=df['At Bat'],y=df['Earned Runs Average'],hue=df['Errors'], cmap=('Spectral'))
plt.xlabel('At Bat', fontsize =16)
plt.ylabel('Earned Runs Average',fontsize =16)
# Out:
# Text(0, 0.5, 'Earned Runs Average')

# %% [markdown]
# # Comment-

# %% [markdown]
# It doesnot give any significant information than high ERA.

# %% [markdown]
# # Boxplot of Features

# %%
plt.figure(figsize=(18,15), facecolor='white')
plotnumber = 1
for column in df:
    if plotnumber <=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column], palette='hsv')
        plt.xlabel(column, fontsize=20)
        plotnumber+=1
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Comments

# %% [markdown]
# 1.There are some outliers present in data.
#
# 2.Shutouts are rare but completely possible with exceptional performance.
#
# 3.Run scored has one outliers but as Runs is most importent parameter,it will be wise to remove corresponding datapoint.
#
# 4.Outliers in Erors are totally possible but no need to worry about it.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Base on Ball", data=df, palette='PiYG')
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Scored", data=df, palette='PiYG')
plt.show()

# %% [markdown]
# # Comments-

# %% [markdown]
# 1.Runs scoredabove 600 is benchmark for winnning in any scenerio.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Average", data=df, palette='gist_earth')
plt.title('Bar Plot Of Wins Vs Average Runs')
plt.show()

# %% [markdown]
# # Comment-

# %% [markdown]
# 1.We can see average runs decreases with increase in wins.
#
#  2.More rubn average give advantage to hitter and here as wins are high even at low run this clearly means that performance of      pitcher is better than hitter.

# %% [markdown]
# # Relation of wins like parameter ERA

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Earned Runs Average", data=df, palette='spring')
plt.xlabel('Wins', fontsize=16)
plt.ylabel("Earned Runs Average", fontsize=16)
plt.show()

# %% [markdown]
# # Comments-

# %% [markdown]
# ERA is low for maximum wins.
#
# ERA and run average run score are bound to related with each other in linear relationship may be positive or negative.
#
# Erned runs and wins must have -ve relationship

# %%
# CHECKING THE RELATION BETWEEN TWO VARIABLES

sns.set_palette('Set1')
plt.figure(figsize=[16,8])
plt.title('Comparison between Run Average and Earned Runs Average', fontsize=20)
sns.scatterplot(x=df['Runs Average'],y=df['Earned Runs Average'],hue=df['Wins'])
plt.xlabel('Runs Average', fontsize =16)
plt.ylabel('Earned Runs Average',fontsize =16)
# Out:
# Text(0, 0.5, 'Earned Runs Average')

# %% [markdown]
# Strike out are randomly placed giving not much any significant insight.

# %% [markdown]
# #There is one outlier in Run Scores, let check that entry.

# %%
df['Runs Scored'].max()
# Out:
# 891

# %%
df.loc[df['Runs Scored']==891]
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  Base on Ball  \
# 5    93          891    5509  1480      308       17        232           570
#
#    Strike Out  Stolen Base  Runs Average  Earned Runs  Earned Runs Average  \
# 5        1151           88           670          609                  3.8
#
#    Complete Games  Shut Out  Saves  Errors
# 5               7        10     34      88

# %% [markdown]
# It seems like highest Doubles ,Homeruns and base ball also belong to this entry.

# %%
df['Home Runs'].max(),df['Base on Ball'].max(),df['Doubles'].max()
# Out:
# (232, 570, 308)

# %% [markdown]
# # Earned Runs\Earned Runs Average\Wins have -ve relationship. lets have check.

# %%
sns.jointplot(x='Earned Runs', y='Wins', data=df, color='blue', palette= 'Set1')

# %%
sns.jointplot(x='Earned Runs', y='Wins', data=df, color='green', palette= 'Set1')

# %% [markdown]
# So the plot shows linear -ve relationship between Earned Runs, Eraned Run Average and wins.

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x='Saves', y='Wins', data=df, color='purple')

# %%
sns.pairplot(df, hue="Wins")

# %%
plt.figure(figsize=(17,12))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Outliar Detection and Removal

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
print("\033[1m"+'Shape of dataset after removing outliers :'+"\033[0m",df1.shape)

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((30-29)/30)*100,'%')

# %% [markdown]
# # Feature Selection and Engineering

# %% [markdown]
# Skewness of Features

# %%
df1.skew()

# %% [markdown]
# Optimal ranege of Skewness id -0.5 to 0.5.

# %% [markdown]
# # Boxcox Transformation

# %%
from scipy.stats import boxcox

# %%
df1['Hits']=boxcox(df1['Hits'],-2)

# %%
df1['Shut Out']=boxcox(df1['Shut Out'],0.5)

# %%
df1['Saves']=boxcox(df1['Saves'],0.5)

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer

# %%
EC=['Errors','Complete Games']
ds =df1[EC].copy()

# %%
column_trans =ColumnTransformer(
    [  ('Errors',PowerTransformer(method='yeo-johnson',standardize=True),['Errors']),
      ('Complete Game',PowerTransformer(method='yeo-johnson',standardize=True),['Complete Games'])])
transformed_yeojohnson =column_trans.fit_transform(df1)   
new_cols=['Errors','Complete Games']
dataset=pd.DataFrame(transformed_yeojohnson,columns=new_cols) #to convert numpy array back into dataframe
pd.concat([dataset],axis=1)
dataset.head()

# %%
# reseting index and mergeing transform data
df1.reset_index(drop=True, inplace=True)
dataset.index=df1.index
df1[EC]=dataset[EC]

# %% [markdown]
# # Skewness After Transforming Features

# %%
df1.skew()

# %% [markdown]
# All features skewness is now transform within permissible limit of -0.5 to 0.5 as shown above

# %% [markdown]
# # 2. Corrleation

# %%
df1.corr()

# %%
upper_triangle = np.triu(df.corr())
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df1.corr()['Wins'].drop(['Wins']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Wins',fontsize=15)
plt.title('Correlation of features with Target Variable win',fontsize = 18)
plt.show()

# %% [markdown]
# bats, Complete game and errors are very poorly correlated with target variable.
#
# Saves, ERA,RA,EA are highly correleated with target variable.
#
# here is visible multi colinearity between the feature columns "Earned Runs", "Earned Run Average" and "Runs Average". This need to check.

# %% [markdown]
# # 3. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features']= df1.columns
vif

# %% [markdown]
# It is natural to have such high multicollinearity due to following reason :-
#
# Earned Run Average,Earned Runs,Runs Average are highly correlated with each other.
#
# At Bat and Hits are 0.771 correlated with each other. But at same time very poor correlated with target variable.
#
# Another most important reason is data need to scale which we did not scale until now.

# %% [markdown]
# # Standard Scalling

# %%
X=df1.drop(columns =['Wins'])
Y=df1['Wins']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %% [markdown]
# AS per the graph, we can see that 7 principal components attribute for 95% of variation in the data. We shall pick the first 7 components for our prediction

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(7))

# %% [markdown]
# # Checking multicolinearity after applying PCA

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(principle_x.values,i) for i in range(principle_x.shape[1])]
vif['Features']= principle_x.columns
vif

# %% [markdown]
# We can see that Multicollinearity issue is clear now.

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)

# %% [markdown]
# # Finding Best Random Sate

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=i, test_size=.25)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)

# %% [markdown]
# # Linear Regression :Base Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=217, test_size=.25)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)

# %% [markdown]
# # Linear Regression Evalution Matrix

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))

# %% [markdown]
# # Cross Validation

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, principle_x, Y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())

# %%
plt.figure(figsize=(6,5))
y_pred=lin_reg.predict(X_test)
sns.swarmplot(x=df['True ValueS'],y=df['Predictions'],(Y_test.round(2), y_pred))
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()

# %% [markdown]
# # Finding best n_neighbors for KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(10):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(10), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# At k= 4, we get the minimum RMSE value which approximately 5.050525962709231, and shoots up on further increasing the k value. We can safely say that k=4 will give us the best result in this case

# %% [markdown]
# # Applying other Regression Moddel , Evolution and Cross Validation

# %%
rf = RandomForestRegressor(n_estimators = 250 ,max_depth=6)
svr=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
dtc = DecisionTreeRegressor(criterion='mse')
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor( max_depth=6,learning_rate=0.1)
knn=KNeighborsRegressor(n_neighbors=4,algorithm='kd_tree')
ls= Lasso(alpha=1e-2, normalize=True, max_iter=1e5)
rd=Ridge(alpha=1e-2, normalize=True)
xgb=XGBRegressor()
model = [rf,ls,rd,svr,dtc,adb,gradb,knn,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    
    # Cross Validation
    score = cross_val_score(m, principle_x, Y, cv =4)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')

# %%
from sklearn.model_selection import GridSearchCV

parameter = {'alpha':np.array([1,0.5,0.1,0.01,0.001,0.0001]),
             'fit_intercept': [True,False],'normalize':[True,False],
             'max_iter':[250,500,1000,1500],'random_state':np.arange(100),
             'selection':["cyclic","random"]}

# %%
GCV = GridSearchCV(Lasso(),parameter,cv=5,n_jobs = -1,verbose = 3)

# %%
GCV.fit(X_train,Y_train)

# %%
GCV.get_params_

# %% [markdown]
# # Final Model

# %%
Final_mod = Lasso(alpha = 0.5, fit_intercept= True, normalize = False,
                                           max_iter = 250, random_state = 32,selection ='random')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')

# %%
plt.figure(figsize=(6,5))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
